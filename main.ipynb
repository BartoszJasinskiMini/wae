# %%
! python ex.py
# Out:
# mkl is not installed
# setting mkl threads num to 1
# COCO INFO: Results will be output to folder exdata\MOCMAES_of_mocmaes_10D_on_bbob-biobj
# *** benchmarking MOCMAES from mocmaes on suite bbob-biobj ***
# 2D 14h02:58s
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# ...
