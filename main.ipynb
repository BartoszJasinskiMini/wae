# %%
! python ex.py
# Out:
# mkl is not installed
# setting mkl threads num to 1
# COCO INFO: Results will be output to folder exdata\MOCMAES_of_mocmaes_2D_on_bbob-biobj
# *** benchmarking MOCMAES from mocmaes on suite bbob-biobj ***
# 2D 8h52:07s
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# .......... .......... .......... .......... ..........
# ...
